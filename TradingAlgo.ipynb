# %% [markdown]
# # Trading Algorithm

# %% [markdown]
# In this notebook we will find a basket of securities which did relativly well under COVID and the try to determine a model to predict the return of these stocks to be used to find strong stocks to invest in for future black swan events like COVID

# %% [markdown]
# ## The Data

# %% [markdown]
# We will be getting out list of securities from running a PCA analysis on the S&P 500 during the rise of COVID. By using PCA we can extract the stocks which made up the positive trend in the S&P 500
#
# the fundametal data will be obttained from Quandl's Core US Fundamentals Data database; this is a paid service!
#
# Closing price will be obtained from yahoo finance using the yFinance library

# %% [markdown]
# ### Obtaining Data

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import bs4 as bs
import requests
import yfinance as yf
import datetime
import numpy as np
import pandas as pd

resp = requests.get('http://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
soup = bs.BeautifulSoup(resp.text, 'lxml')
table = soup.find('table', {'class': 'wikitable sortable'})
tickers = []
for row in table.findAll('tr')[1:]:
    ticker = row.findAll('td')[0].text
    tickers.append(ticker)

tickers = [s.replace('\n', '') for s in tickers]
start = datetime.datetime(2020,1,1)
end = datetime.datetime(2020,8,31)
data = yf.download(tickers, start=start, end=end)
# Out:
# [*********************100%***********************]  505 of 505 completed
#
# 2 Failed downloads:
# - BF.B: No data found for this date range, symbol may be delisted
# - BRK.B: No data found, symbol may be delisted

# %%
#Slice Open Prices
sp500_open=data.iloc[:, data.columns.get_level_values(0)=='Open']
sp500_open.head()
#Slice Adj. Close Prices
sp500_adjclose=data.iloc[:, data.columns.get_level_values(0)=='Adj Close']
#sp500_adjclose.dropna(axis = 1, inplace = True)
sp500_adjclose.head()

sp500_adjclose.drop(['BF.B','BRK.B'], axis=1, level=1,inplace = True)
sp500_adjclose.shape
# Out:
# (168, 503)

# %%
def save_sp500_tickers():

    resp = requests.get('http://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
    soup = bs.BeautifulSoup(resp.text, 'html')
    table = soup.find('table', {'class': 'wikitable sortable'})
    tickers = []
    for row in table.findAll('tr')[1:]:
        ticker = row.findAll('td')[0].text
        if not '.' in ticker:
            tickers.append(ticker.replace('\n',''))
        
    return tickers

tickers = save_sp500_tickers()

# %%
prices = yf.download(tickers, start='2020-01-01')['Adj Close']
# Out:
# [*********************100%***********************]  503 of 503 completed

# %%
rs = sp500_adjclose.apply(np.log).diff(1)

# %%
import matplotlib.pyplot as plt

rs.plot(legend=0, figsize=(10,6), grid=True, title='Daily Returns of the Stocks in the S&P500')
plt.tight_layout()
plt.savefig('tmp.png')
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\sinth\anaconda3\envs\pyvizenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
(rs.cumsum().apply(np.exp)).plot(legend=0, figsize=(10,6), grid=True, title='Cumulative Returns of the Stocks in the S&P500')
plt.tight_layout()
plt.savefig('tmp.png')

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(1).fit(rs.fillna(0))

# %%
#index_column = rs.columns.droplevel(level=0)

pc1 = pd.Series(index=rs.columns, data=pca.components_[0])

#pc1 = pd.Series(index=index_column, data=pca.components_[0])

pc1.plot(figsize=(10,6), xticks=[], grid=True, title='First Principal Component of the S&P500')
plt.tight_layout()
plt.savefig('tmp.png')

# %%
weights = abs(pc1)/sum(abs(pc1))
myrs = (weights*rs).sum(1)
myrs.cumsum().apply(np.exp).plot()

# %%
prices = yf.download(['SPY'], start=start, end=end)['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
rs_df = pd.concat([myrs, prices.apply(np.log).diff(1)], 1)
rs_df.columns = ["PCA Portfolio", "S&P500"]

rs_df.dropna().cumsum().apply(np.exp).plot(subplots=True, figsize=(10,6), grid=True, linewidth=3);
plt.tight_layout()
plt.savefig('tmp.png')

# %%
fig, ax = plt.subplots(2,1, figsize=(10,6))
pc1.nsmallest(10).plot.bar(ax=ax[0], color='green', grid=True, title='Stocks with Most Negative PCA Weights')
pc1.nlargest(10).plot.bar(ax=ax[1], color='blue', grid=True, title='Stocks with Least Negative PCA Weights')

plt.tight_layout()
plt.savefig('tmp.png')

# %%
myrs = rs[pc1.nlargest(50).index].mean(1)
myrs.cumsum().apply(np.exp).plot(figsize=(15,5), grid=True, linewidth=3, title='PCA Portfolio vs. S&P500')
prices['2020':].apply(np.log).diff(1).cumsum().apply(np.exp).plot(figsize=(10,6), grid=True, linewidth=3)
plt.legend(['PCA Selection', 'S&P500'])

plt.tight_layout()
plt.savefig('tmp.png')

# %%
stock_list = pc1.nlargest(50)

# %%
stock_list = stock_list.index.droplevel(level=0)

# %%
security_basket = stock_list.tolist()

# %%
# Authenticating Quandl API for fundamental data
import os
from dotenv import load_dotenv
import quandl

load_dotenv()

QUANDL_API_KEY = os.getenv("QUANDL_API_KEY")
quandl.ApiConfig.api_key= QUANDL_API_KEY

# %%
from quandl.errors.quandl_error import NotFoundError #to catch errors due to symbols


def get_factors(security_basket,start_date, end_date):
    '''
    
    Takes securities from a security basket and pulls daily fundamental indicators
    for each security as well as the closing price
    
    Parameters
    ----------
    
    security_basket: list of str
                    representing tickers.
    
    Returns
    ----------
    
    dataframe of fundamental data and closing price.
    '''
    SP_500 = yf.download('^GSPC', start=start_date, end=end_date) 
    price_df = yf.download(security_basket, start=start_date, end=end_date)    
    portfolio_df = pd.DataFrame()
    for security in security_basket:
        try:
            security_df = quandl.get_table('SHARADAR/DAILY', ticker= security)
            security_df = security_df.set_index('date')
            security_df = security_df.sort_index()
            security_df['close'] = price_df['Close'][security]
            security_df['SP_close'] = SP_500['Close']
            portfolio_df = portfolio_df.append(security_df) 
        except NotFoundError: # if symbol is not found move on to  the next symbol
            pass
    return portfolio_df

# %%
start_date = datetime.datetime(2015,1,1) # 2015 was chosen as the start date due to historical limitations of Quandl data 
end_date = datetime.datetime(2020,9,25)
df = get_factors(security_basket, start_date, end_date) # using tickers to create a dataframe with features
# Droping any securities were we wwere not able to get all the information
df.dropna(
    axis=0,
    how='any',
    thresh=None,
    subset=None,
    inplace=True
)

# Since we are using paid data we are saving everything into a csv and then reimporting
df.to_csv('data.csv') 
df = pd.DataFrame.from_csv('data.csv')
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  50 of 50 completed
#            ticker lastupdated       ev  evebit  evebitda  marketcap   pb  \
# date
# 2015-01-02     KR  2018-10-18  42485.8    14.5       8.8    31213.8  5.9
# 2015-01-05     KR  2018-10-18  42264.7    14.5       8.8    30992.7  5.8
# 2015-01-06     KR  2018-10-18  42264.7    14.5       8.8    30992.7  5.8
# 2015-01-07     KR  2018-10-18  43203.2    14.8       9.0    31931.2  6.0
# 2015-01-08     KR  2018-10-18  43797.7    15.0       9.1    32525.7  6.1
#
#               pe   ps      close     SP_close
# date
# 2015-01-02  19.1  0.3  31.764999  2058.199951
# 2015-01-05  19.0  0.3  31.540001  2020.579956
# 2015-01-06  19.0  0.3  31.540001  2002.609985
# 2015-01-07  19.6  0.3  32.494999  2025.900024
# 2015-01-08  19.9  0.3  33.099998  2062.139893

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# Now that we have all the data that, we need we need to create a label and add factor that pretain to technical signals. Our label will be a simple buy or sell indicator based on whether the return greater than the S&P 500 return and positive.

# %%
def create_label(df, security_colunm, benchmark_column):
    '''
    
    calculate whether the 3 month return of a security was positive and beat the 
    3 month return of the benchmark with 1 representing the day the positive 
    return beat the benchamark and 0 representing a day when it was not
    
    Parameters
    ----------
    
    df: dataframe
        Should contain the closing price of the security and the benchmark 
    
    security_colunm: str
        name of column that contains the security closing prices
    
    benchmark_column: str
        name of column that contains the benchmark closing price
    
    Returns
    ----------
    
    copy of inputed dataframe with an added column indicating whether 
    the 3 month returns from security met the criteria or not
    
    '''
    df['return'] = df[security_colunm].rolling(90, min_periods=90).mean().pct_change()
    df['SP_return'] = df[benchmark_column].rolling(90, min_periods=90).mean().pct_change()
    df = df.dropna()
    df['good_trade'] = (df['return'] > 0).astype(int) * (df['return'] > df['SP_return']).astype(int)
    return df

# %%
df = df.dropna()
df = create_label(df, 'close', 'SP_close')

# %%
df.head()
# Out:
#            ticker lastupdated       ev  evebit  evebitda  marketcap   pb  \
# date
# 2015-05-13     KR  2018-10-18  46369.5    14.9       9.2    34981.5  6.5
# 2015-05-14     KR  2018-10-18  46963.8    15.1       9.3    35575.8  6.6
# 2015-05-15     KR  2018-10-18  47287.9    15.2       9.3    35899.9  6.6
# 2015-05-18     KR  2018-10-18  47283.0    15.2       9.3    35895.0  6.6
# 2015-05-19     KR  2018-10-18  47469.6    15.2       9.4    36081.6  6.7
#
#               pe   ps      close     SP_close    return  SP_return  good_trade
# date
# 2015-05-13  20.2  0.3  35.615002  2098.479980  0.001192   0.000216           1
# 2015-05-14  20.6  0.3  36.220001  2121.100098  0.001447   0.000538           1
# 2015-05-15  20.8  0.3  36.549999  2122.729980  0.001547   0.000643           1
# 2015-05-18  20.8  0.3  36.544998  2129.199951  0.001249   0.000553           1
# 2015-05-19  20.9  0.3  36.735001  2127.830078  0.001119   0.000351           1

# %% [markdown]
# ### Technical signals
#
# We will now use the closing price to create some technical signals. To create the signals we are using the following:
#
# **Simple moving average:**
#
# >SMA = (A<sub>1</sub>+A<sub>2</sub>+...+A<sub>n</sub>)/n
#
# > ***where:***
#
# >A = Average in period n
#
# >n = number of time periods
#
# **Exponential Moving Average:**
#
# >EMA<sub>t</sub> =[V<sub>t</sub> * (s/1+d)]+EMA<sub>y</sub> * [1−(s/1+d )]
#
# > ***where:***
#
# >EMA<sub>t</sub> = EMA today
#
# >V<sub>t</sub> = Value today
#
# >EMA<sub>y</sub> = EMA Yesterday
#
# >s = smoothing
#
# >d = number of days
#
# **Rate of Change**
#
# > ROC = (Y<sub>2</sub> - Y<sub>1</sub>)/ (X<sub>2</sub> - X<sub>1</sub>)
#
# > **Where**
#
# >Y = price
#
# >X = period
#
# **Price Momentum**
#
# **Bollinger Bands**

# %%
def MA(df, n):
    '''
    
    calculates the moving average
    
    Parameters
    ----------
    
    df: dataframe
        dataframe with closing price
        
    n: int
        Window for moving average
    
    Returns
    ----------
    
    Series with the moving average
    
    '''
    MA = pd.Series(df["close"].rolling(n, min_periods=n).mean())
    return MA

# %%
def EMA(data, n):
    '''
    
    calculates the exponential moving average
    
    Parameters
    ----------
    
    df: dataframe
        dataframe with closing price
        
    n: int
        Window for moving average
    
    Returns
    ----------
    
    Series with the exponential moving average
    
    '''
    EMA = pd.Series(df['close'].ewm(span=n, min_periods=n).mean())
    return EMA

# %%
def ROC(data, n):
    '''
    
    calculates the rate of change
    
    Parameters
    ----------
    
    data: Series
        series of closing price
        
    n: int
        Window for moving average
    
    Returns
    ----------
    
    Series with the rate of change
    
    '''
    M = data.diff(n - 1)  
    N = data.shift(n - 1)  
    ROC = pd.Series(((M / N) * 100))   
    return ROC

# %%
def MOM(data, n): 
    '''
    
    calculates the price momentum
    
    Parameters
    ----------
    
    data: Series
        series of closing price
        
    n: int
        Window for moving average
    
    Returns
    ----------
    
    Series with the price momentum
    
    '''
    MOM = pd.Series(data.diff(n))   
    return MOM

# %%
def bolinger(df, bollinger_window):
    '''
    
    calculates various bollinger bands
    
    Parameters
    ----------
    
    df: dataframe
        dataframe with closing prices
        
    n: int
        Window for moving average
    
    Returns
    ----------
    
    input dataframe with new column reprsenting the various bollinger bands
    
    '''
    # Calculate rolling mean and standard deviation
    df['bollinger_mid_band'] = df['close'].rolling(window=bollinger_window).mean()
    df['bollinger_std'] = df['close'].rolling(window=bollinger_window).std()

    # Calculate upper and lowers bands of bollinger band
    df['bollinger_upper_band']  = df['bollinger_mid_band'] + (df['bollinger_std'] * 1)
    df['bollinger_lower_band']  = df['bollinger_mid_band'] - (df['bollinger_std'] * 1)

    # Calculate bollinger band trading signal
    df['bollinger_long'] = np.where(df['close'] < df['bollinger_lower_band'], 1.0, 0.0)
    df['bollinger_short'] = np.where(df['close'] > df['bollinger_upper_band'], -1.0, 0.0)
    df['bollinger_signal'] = df['bollinger_long'] + df['bollinger_short']
    
    return df

# %%
def make_technical_signals(df, short_window, long_window):
    '''
    
    creates trade signals based on technical indiacators
    
    Parameters
    ----------
    
    df: dataframe
        dataframe with the close price
    
    short_window: integer
        short window
    
    long_window: integer
        long window
        
    Returns
    ----------
    
    returns the inputed dataframe with trade signals
    
    '''
    # get short and long term simple moving averages
    df[f'MA {short_window}'] = MA(df, short_window)
    df[f'MA {long_window}'] = MA(df, long_window)
    
    # get short and long term exponential moving averages
    df[f'EMA {short_window}'] = MA(df, short_window)
    df[f'EMA {long_window}'] = MA(df, long_window)
    
    
    df['ROC21'] = ROC(df['close'], 21)
    df['ROC63'] = ROC(df['close'], 63)
    
    df['MOM21'] = MOM(df['close'], 21)
    df['MOM63'] = MOM(df['close'], 63)
    
    bollinger_window = 20
    df = bolinger(df, bollinger_window)
    return df.dropna()

# %%
df = make_technical_signals(df, 50, 100)
df.head()
# Out:
#            ticker lastupdated       ev  evebit  evebitda  marketcap   pb  \
# date
# 2015-10-02     KR  2018-10-18  47155.4    13.8       8.7    36153.4  6.1
# 2015-10-05     KR  2018-10-18  48060.6    14.0       8.8    37058.6  6.3
# 2015-10-06     KR  2018-10-18  47145.6    13.8       8.7    36143.6  6.1
# 2015-10-07     KR  2018-10-18  47515.5    13.9       8.7    36513.5  6.2
# 2015-10-08     KR  2018-10-18  47992.5    14.0       8.8    36990.5  6.3
#
#               pe   ps      close  ...     ROC63     MOM21     MOM63  \
# date                              ...
# 2015-10-02  18.7  0.3  37.139999  ... -1.472345  2.489998  0.355000
# 2015-10-05  19.2  0.3  38.070000  ...  1.317362  3.500000  0.375000
# 2015-10-06  18.7  0.3  37.130001  ... -1.733489  3.060001 -0.445000
# 2015-10-07  18.9  0.3  37.509998  ... -1.729106  2.459999 -0.275002
# 2015-10-08  19.1  0.3  38.000000  ... -1.234564  3.599998 -0.169998
#
#             bollinger_mid_band  bollinger_std  bollinger_upper_band  \
# date
# 2015-10-02             36.2485       0.980254             37.228754
# 2015-10-05             36.4485       0.918495             37.366995
# 2015-10-06             36.5525       0.868191             37.420691
# 2015-10-07             36.7080       0.729863             37.437863
# 2015-10-08             36.8380       0.716046             37.554046
#
#             bollinger_lower_band  bollinger_long  bollinger_short  \
# date
# 2015-10-02             35.268246             0.0              0.0
# 2015-10-05             35.530005             0.0             -1.0
# 2015-10-06             35.684309             0.0              0.0
# 2015-10-07             35.978137             0.0             -1.0
# 2015-10-08             36.121954             0.0             -1.0
#
#             bollinger_signal
# date
# 2015-10-02               0.0
# 2015-10-05              -1.0
# 2015-10-06               0.0
# 2015-10-07              -1.0
# 2015-10-08              -1.0
#
# [5 rows x 29 columns]

# %% [markdown]
# Now that we have several features, to simplify the model we will be removing the features that do not impact the good trade signal. To figure out which features hold the least amount of importance we will be running a XGBoost classifier and using the feature importance function. We will first split the features from the label, then split our X and y into training and testing and then scale the train and test feature data for the non binary features

# %%
X = df.reset_index().drop(columns=['ticker', 'lastupdated', 'good_trade','date','close','SP_close','return','SP_return']) # getting all the features
y = df['good_trade'] # getting the label

# %%
X.head()
# Out:
#         ev  evebit  evebitda  marketcap   pb    pe   ps    MA 50    MA 100  \
# 0  47155.4    13.8       8.7    36153.4  6.1  18.7  0.3  36.7386  36.83400
# 1  48060.6    14.0       8.8    37058.6  6.3  19.2  0.3  36.7328  36.85855
# 2  47145.6    13.8       8.7    36143.6  6.1  18.7  0.3  36.7114  36.86765
# 3  47515.5    13.9       8.7    36513.5  6.2  18.9  0.3  36.6872  36.87725
# 4  47992.5    14.0       8.8    36990.5  6.3  19.1  0.3  36.6712  36.89180
#
#     EMA 50  ...     ROC63     MOM21     MOM63  bollinger_mid_band  \
# 0  36.7386  ... -1.472345  2.489998  0.355000             36.2485
# 1  36.7328  ...  1.317362  3.500000  0.375000             36.4485
# 2  36.7114  ... -1.733489  3.060001 -0.445000             36.5525
# 3  36.6872  ... -1.729106  2.459999 -0.275002             36.7080
# 4  36.6712  ... -1.234564  3.599998 -0.169998             36.8380
#
#    bollinger_std  bollinger_upper_band  bollinger_lower_band  bollinger_long  \
# 0       0.980254             37.228754             35.268246             0.0
# 1       0.918495             37.366995             35.530005             0.0
# 2       0.868191             37.420691             35.684309             0.0
# 3       0.729863             37.437863             35.978137             0.0
# 4       0.716046             37.554046             36.121954             0.0
#
#    bollinger_short  bollinger_signal
# 0              0.0               0.0
# 1             -1.0              -1.0
# 2              0.0               0.0
# 3             -1.0              -1.0
# 4             -1.0              -1.0
#
# [5 rows x 22 columns]

# %%
y.head()
# Out:
# date
# 2015-10-02    1
# 2015-10-05    1
# 2015-10-06    1
# 2015-10-07    1
# 2015-10-08    1
# Name: good_trade, dtype: int32

# %% [markdown]
# **Prior to running our model we need to scale out data. From the histograms we can say that our data is not normally distributed therefore when scaling data we will opt for the minmax scaler.**

# %%
X.hist(figsize =(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C8A78D1D08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8A78CB588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8A78DD448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8A78F5348>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8A781A908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C8A7833748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8A782CB48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8A77878C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8A7799A88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8A7786988>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C8A79BA848>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8A7582288>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8A758FD08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8A9313D08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8A8E68748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C8A79338C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8A8E66748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8A8E60F08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8A791EE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8A74A4C48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C8A8F05848>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8A74AC208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8A8F0D608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8A8FDCF08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C8A93C5288>]],
#       dtype=object)

# %%
# Splitting into Train and Test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=0)


from sklearn.preprocessing import MinMaxScaler

# Creating StandardScaler instance
scaler = MinMaxScaler()

# Fitting Standard Scaler
X_scaler = scaler.fit(X_train)

# Scaling data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# adding back scaled data
X_train[list(X_train.columns) ] = X_train_scaled
X_test[list(X_test.columns) ] = X_test_scaled

# %%
from xgboost import XGBClassifier
from xgboost import plot_importance
from matplotlib import pyplot

# fit model on training data
model = XGBClassifier()
model.fit(X_train, y_train)

# plot feature importance
plot_importance(model)
pyplot.show()

# %% [markdown]
# The f with the numeric subscript tells us the index 0 to 6 which is based off of the feature columns from the X_train dataframe. We can then conclude in accordance to importance the feature are ranked as follows:
#
# 100 day moving average
#
# 50 day moving average
#
# pe - price to earnings
#
# EV - Enterprise value
#
# pb - price to book
#
# evebit - earnings before interest and taxes
#
# evebitda - earnings before interest and taxes and amortization
#
# 63 day rate of change
#
# MarketCap
#
# 63 day price momentum
#
# bollinger standard deviation
#
# bollinger upper band
#
# ps - price to sales
#
# bollinger lower band
#
# 21 day price momentum
#
# bollinger mid band
#
# 21 day rate of change
#
# bollinger long
#
# bollinger short
#
#
# We will drop the bottom two when doing our regression model.

# %% [markdown]
# ## Predicting Future Returns Using Regression

# %%
from sklearn.metrics import mean_squared_error, r2_score
from xgboost import XGBRegressor


def runPredictions(X, y, security):
    '''
    returns graphs with the predicted and actual returns and RMSE score. Predictions are obtained using XGBoost regressor.

    Parameters
    ----------
    
    X:  dataframe
        Dataframe of features
    
    y: Series
        Series of returns that will be predicted
    
    Security: string
        Ticker symbol
        
    Returns
    ----------
    
    plot object with the predicted and actual return of the stock, and the RMSE of the prediction
    
    '''
    total_rows = len(X.index)
    train_index = 0.7 * total_rows
    X_train = X.loc[:train_index]
    X_test  = X.loc[train_index:]
    y_train  = y.loc[:train_index]
    y_test = y.loc[train_index:]

    # Creating StandardScaler instance
    scaler = MinMaxScaler()

    # Fitting Standard Scaler
    X_scaler = scaler.fit(X_train)

    # Scaling data
    X_train_scaled = X_scaler.transform(X_train)
    X_test_scaled = X_scaler.transform(X_test)

    
    # fit model on training data
    model = XGBRegressor()
    model.fit(X_train_scaled, y_train)
    
    # Get predictions
    predict = model.predict(X_test_scaled)
    # Set mean-squared-error
    mse = mean_squared_error(
        y_test.to_list(),
        predict
    )

    # Using that mean-squared-error, calculate the root-mean-squared error (RMSE):
    out_of_sample_rmse = np.sqrt(mse)
    
    
    plt.plot(predict, label = "prediction")
    plt.plot(y_test.to_list(), label = "actual")
    plt.title(f'{security}: Actual Versus Predicted')
    plt.legend()
    return plt, out_of_sample_rmse

# %%
dict = {}
for security in security_basket: 
    X = df.loc[df['ticker'] == security ].reset_index().drop(columns=['ticker', 'lastupdated', 'good_trade','date','close','SP_close','return','SP_return', 'bollinger_long', 'bollinger_short']) # getting all the features
    y = df.loc[df['ticker'] == security ].reset_index().drop(columns='date')['return'] # getting the label
    plt, out_of_sample_rmse = runPredictions(X, y, security)
    dict[security] = out_of_sample_rmse
    plt.show()
    plt.close()
    print(f"\nOut-of-Sample Root Mean Squared Error (RMSE) for {security}: {out_of_sample_rmse}\n\n")
# Out:
# Out-of-Sample Root Mean Squared Error (RMSE) for KR: 0.0010683762412653929
# Out-of-Sample Root Mean Squared Error (RMSE) for CLX: 0.0010054715152493573
# Out-of-Sample Root Mean Squared Error (RMSE) for LUMN: 0.0006129072948613405
# Out-of-Sample Root Mean Squared Error (RMSE) for CPB: 0.000993403018485096
# Out-of-Sample Root Mean Squared Error (RMSE) for SJM: 0.0026573240501101833
# Out-of-Sample Root Mean Squared Error (RMSE) for CTXS: 0.0012717877880908176
# Out-of-Sample Root Mean Squared Error (RMSE) for GIS: 0.0015205412892681414
# Out-of-Sample Root Mean Squared Error (RMSE) for REGN: 0.0033981370233250254
# Out-of-Sample Root Mean Squared Error (RMSE) for HRL: 0.0013088504445367707
# Out-of-Sample Root Mean Squared Error (RMSE) for TIF: 0.0021700724453038796
# Out-of-Sample Root Mean Squared Error (RMSE) for NEM: 0.00506240969298701
# Out-of-Sample Root Mean Squared Error (RMSE) for OTIS: 0.003976307265280048
# Out-of-Sample Root Mean Squared Error (RMSE) for CAG: 0.0029111968149175033
# Out-of-Sample Root Mean Squared Error (RMSE) for GILD: 0.0028702441763573845
# Out-of-Sample Root Mean Squared Error (RMSE) for WMT: 0.0015936668967721824
# Out-of-Sample Root Mean Squared Error (RMSE) for DPZ: 0.0011607644378718342
# Out-of-Sample Root Mean Squared Error (RMSE) for K: 0.0008436020525551112
# Out-of-Sample Root Mean Squared Error (RMSE) for DG: 0.000775859042170244
# Out-of-Sample Root Mean Squared Error (RMSE) for CHD: 0.013037585021338125
# Out-of-Sample Root Mean Squared Error (RMSE) for AKAM: 0.000835497018765124
# Out-of-Sample Root Mean Squared Error (RMSE) for ATVI: 0.0019147157213443564
# Out-of-Sample Root Mean Squared Error (RMSE) for EA: 0.002019621809287822
# Out-of-Sample Root Mean Squared Error (RMSE) for NLOK: 0.0030947964416501083
# Out-of-Sample Root Mean Squared Error (RMSE) for CARR: 0.0010895993426327404
# Out-of-Sample Root Mean Squared Error (RMSE) for AMZN: 0.0010399025744483898
# Out-of-Sample Root Mean Squared Error (RMSE) for TTWO: 0.0015186613377872016
# Out-of-Sample Root Mean Squared Error (RMSE) for COST: 0.0007154546177426744
# Out-of-Sample Root Mean Squared Error (RMSE) for NFLX: 0.0020751866257365937
# Out-of-Sample Root Mean Squared Error (RMSE) for BDX: 0.0011518701483072314
# Out-of-Sample Root Mean Squared Error (RMSE) for CHRW: 0.0009274449331317432
# Out-of-Sample Root Mean Squared Error (RMSE) for VZ: 0.003045834703242411
# Out-of-Sample Root Mean Squared Error (RMSE) for KMB: 0.0006268795438891736
# Out-of-Sample Root Mean Squared Error (RMSE) for EBAY: 0.004058914229869258
# Out-of-Sample Root Mean Squared Error (RMSE) for TYL: 0.0011606190535858984
# Out-of-Sample Root Mean Squared Error (RMSE) for ABMD: 0.002268008290904769
# Out-of-Sample Root Mean Squared Error (RMSE) for INCY: 0.0017573477361602348
# Out-of-Sample Root Mean Squared Error (RMSE) for WST: 0.0013886557052777942
# Out-of-Sample Root Mean Squared Error (RMSE) for BMY: 0.001583925581102564
# Out-of-Sample Root Mean Squared Error (RMSE) for JNJ: 0.0007284413919474684
# Out-of-Sample Root Mean Squared Error (RMSE) for LLY: 0.0012475045902045122
# Out-of-Sample Root Mean Squared Error (RMSE) for CL: 0.0007018731367476693
# Out-of-Sample Root Mean Squared Error (RMSE) for BIO: 0.00102061416441922
# Out-of-Sample Root Mean Squared Error (RMSE) for TGT: 0.004280412304047942
# Out-of-Sample Root Mean Squared Error (RMSE) for TMO: 0.001110848383931573
# Out-of-Sample Root Mean Squared Error (RMSE) for PFE: 0.0010560124885458304
# Out-of-Sample Root Mean Squared Error (RMSE) for TSCO: 0.0015159605459619094
# Out-of-Sample Root Mean Squared Error (RMSE) for PG: 0.002316996534302579
# Out-of-Sample Root Mean Squared Error (RMSE) for ED: 0.0008841784263364349
# Out-of-Sample Root Mean Squared Error (RMSE) for ALXN: 0.0026237592598204918
# Out-of-Sample Root Mean Squared Error (RMSE) for MKC: 0.001290948573603285

# %%
rmse_df = pd.DataFrame.from_dict(dict, orient='index')

# %%
rmse_df.sort_values(by=[0])[:10]
# Out:
#              0
# LUMN  0.000613
# KMB   0.000627
# CL    0.000702
# COST  0.000715
# JNJ   0.000728
# DG    0.000776
# AKAM  0.000835
# K     0.000844
# ED    0.000884
# CHRW  0.000927

# %% [markdown]
# **The stocks that we were able to predict the best are as follows: MB, CL, COST, JNJ, DG, CPB0, AKAM, K, LUMN, ED. Overall the RMSE are low meaning the model can be a good predictor of the return for these stocks. You may have noticed some stocks have odd graphs that only cover a short period of time that is becuase of the limited days that we have closing for.**
